# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv")

# %%
df.head()
# Out:
#    Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30/01/20               Kerala                        1
# 1    2  31/01/20               Kerala                        1
# 2    3  01/02/20               Kerala                        2
# 3    4  02/02/20               Kerala                        3
# 4    5  03/02/20               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %%
df.head(50)
# Out:
#     Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0     1  30/01/20               Kerala                        1
# 1     2  31/01/20               Kerala                        1
# 2     3  01/02/20               Kerala                        2
# 3     4  02/02/20               Kerala                        3
# 4     5  03/02/20               Kerala                        3
# 5     6  04/02/20               Kerala                        3
# 6     7  05/02/20               Kerala                        3
# 7     8  06/02/20               Kerala                        3
# 8     9  07/02/20               Kerala                        3
# 9    10  08/02/20               Kerala                        3
# 10   11  09/02/20               Kerala                        3
# 11   12  10/02/20               Kerala                        3
# 12   13  11/02/20               Kerala                        3
# 13   14  12/02/20               Kerala                        3
# ...

# %%
dt = df.groupby('Date')

# %%
dt.head(50)
# Out:
#      Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0      1  30/01/20               Kerala                        1
# 1      2  31/01/20               Kerala                        1
# 2      3  01/02/20               Kerala                        2
# 3      4  02/02/20               Kerala                        3
# 4      5  03/02/20               Kerala                        3
# ..   ...       ...                  ...                      ...
# 265  266  21/03/20    Jammu and Kashmir                        4
# 266  267  21/03/20               Ladakh                       13
# 267  268  21/03/20        Uttar Pradesh                       23
# 268  269  21/03/20          Uttarakhand                        3
# 269  270  21/03/20          West Bengal                        3
#
#      ConfirmedForeignNational  Cured  Deaths
# 0                           0      0       0
# 1                           0      0       0
# 2                           0      0       0
# ...

# %%
df['Confirmed'] =  df['ConfirmedIndianNational'] + df['ConfirmedForeignNational']
df.drop('ConfirmedIndianNational',axis = 1,inplace=True)
df.drop('ConfirmedForeignNational',axis = 1,inplace=True)
df.head()
# Out:
#    Sno      Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0    1  30/01/20               Kerala      0       0          1
# 1    2  31/01/20               Kerala      0       0          1
# 2    3  01/02/20               Kerala      0       0          2
# 3    4  02/02/20               Kerala      0       0          3
# 4    5  03/02/20               Kerala      0       0          3

# %%
new_data = df[df['Date']== '04/03/20'].reset_index()
new_data
# Out:
#    index  Sno      Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0     39   40  04/03/20        Uttar Pradesh      0       0          6
# 1     40   41  04/03/20               Kerala      3       0          3
# 2     41   42  04/03/20              Haryana      0       0          2
# 3     42   43  04/03/20                Delhi      0       0          1
# 4     43   44  04/03/20            Telengana      0       0          1
# 5     44   45  04/03/20            Rajasthan      0       0         15

# %%
ll = df.head(45)

# %%
ll
# Out:
#     Sno      Date State/UnionTerritory  Cured  Deaths  Confirmed
# 0     1  30/01/20               Kerala      0       0          1
# 1     2  31/01/20               Kerala      0       0          1
# 2     3  01/02/20               Kerala      0       0          2
# 3     4  02/02/20               Kerala      0       0          3
# 4     5  03/02/20               Kerala      0       0          3
# 5     6  04/02/20               Kerala      0       0          3
# 6     7  05/02/20               Kerala      0       0          3
# 7     8  06/02/20               Kerala      0       0          3
# 8     9  07/02/20               Kerala      0       0          3
# 9    10  08/02/20               Kerala      0       0          3
# 10   11  09/02/20               Kerala      0       0          3
# 11   12  10/02/20               Kerala      0       0          3
# 12   13  11/02/20               Kerala      0       0          3
# ...

# %%
ll["Confirmed"].sum()
# Out:
# 130

# %%
ll["Cured"].sum()
# Out:
# 6

# %%
ll["Deaths"].sum()
# Out:
# 0

# %%
df1 = df.groupby('Date',sort=False).sum()

# %%
df2 = pd.DataFrame(df1)
df2
# Out:
#            Sno  Cured  Deaths  Confirmed
# Date
# 30/01/20     1      0       0          1
# 31/01/20     2      0       0          1
# 01/02/20     3      0       0          2
# 02/02/20     4      0       0          3
# 03/02/20     5      0       0          3
# 04/02/20     6      0       0          3
# 05/02/20     7      0       0          3
# 06/02/20     8      0       0          3
# 07/02/20     9      0       0          3
# 08/02/20    10      0       0          3
# 09/02/20    11      0       0          3
# 10/02/20    12      0       0          3
# 11/02/20    13      0       0          3
# 12/02/20    14      0       0          3
# 13/02/20    15      0       0          3
# 14/02/20    16      0       0          3
# 15/02/20    17      0       0          3
# 16/02/20    18      0       0          3
# 17/02/20    19      0       0          3
# 18/02/20    20      0       0          3
# 19/02/20    21      0       0          3
# 20/02/20    22      0       0          3
# ...

# %%
df3 = df2.sum(axis=1)
df3
# Out:
# Date
# 30/01/20       2
# 31/01/20       3
# 01/02/20       5
# 02/02/20       7
# 03/02/20       8
# 04/02/20       9
# 05/02/20      10
# 06/02/20      11
# 07/02/20      12
# 08/02/20      13
# 09/02/20      14
# 10/02/20      15
# 11/02/20      16
# 12/02/20      17
# 13/02/20      18
# 14/02/20      19
# 15/02/20      20
# 16/02/20      21
# 17/02/20      22
# 18/02/20      23
# 19/02/20      24
# 20/02/20      25
# 21/02/20      26
# 22/02/20      27
# 23/02/20      28
# 24/02/20      29
# 25/02/20      30
# 26/02/20      31
# 27/02/20      32
# 28/02/20      33
# 29/02/20      34
# 01/03/20      35
# 02/03/20     107
# 03/03/20     159
# 04/03/20     286
# 05/03/20     324
# 06/03/20     361
# 07/03/20     529
# 08/03/20     598
# 09/03/20    1003
# 10/03/20    1159
# 11/03/20    1305
# 12/03/20    1585
# 13/03/20    1762
# 14/03/20    1942
# 15/03/20    2302
# 16/03/20    2679
# 17/03/20    2929
# 18/03/20    3585
# 19/03/20    4358
# 20/03/20    5020
# 21/03/20    6019
# ...

# %%
data=[['30/01/20',2],['31/01/20',3],['01/02/20',5],['02/02/20',7],['03/02/20',8],['04/02/20',9],['05/02/20',10],['06/02/20',11],['07/02/20',12],['08/02/20',13],['09/02/20',14],['10/02/20',15],['11/02/20',16],['12/02/20',17],['13/02/20',18],['14/02/20',19],['15/02/20',20],['16/02/20',21],['17/02/20',22],['18/02/20',23],['19/02/20',24],['20/02/20',25],['21/02/20',26],['22/02/20',27],['23/02/20',28],['24/02/20',29],['25/02/20',30],['26/02/20',31],['27/02/20',32],['28/02/20',33],['29/02/20',34],['01/03/20',35],['02/03/20',107],['03/03/20',159],['04/03/20',286],['05/03/20',324],['06/03/20',361],['07/03/20',529],['08/03/20',598],['09/03/20',1003],['10/03/20',1159],['11/03/20',1305],['12/03/20',1585],['13/03/20',1762],['14/03/20',1942],['15/03/20',2302],['16/03/20',2679],['17/03/20',2929],['18/03/20',3585],['19/03/20',4358],['20/03/20',5020],['21/03/20',6019]]

# %%
datafr = pd.DataFrame(data,columns=['Date','Total_Cases'])
datafr
# Out:
#         Date  Total_Cases
# 0   30/01/20            2
# 1   31/01/20            3
# 2   01/02/20            5
# 3   02/02/20            7
# 4   03/02/20            8
# 5   04/02/20            9
# 6   05/02/20           10
# 7   06/02/20           11
# 8   07/02/20           12
# 9   08/02/20           13
# 10  09/02/20           14
# 11  10/02/20           15
# 12  11/02/20           16
# 13  12/02/20           17
# 14  13/02/20           18
# 15  14/02/20           19
# 16  15/02/20           20
# 17  16/02/20           21
# 18  17/02/20           22
# 19  18/02/20           23
# 20  19/02/20           24
# 21  20/02/20           25
# 22  21/02/20           26
# 23  22/02/20           27
# 24  23/02/20           28
# 25  24/02/20           29
# 26  25/02/20           30
# 27  26/02/20           31
# 28  27/02/20           32
# 29  28/02/20           33
# 30  29/02/20           34
# 31  01/03/20           35
# 32  02/03/20          107
# 33  03/03/20          159
# ...

# %%
#Line graph of data wise cases
fig, ax = plt.subplots()
fig.set_figwidth(20)
fig.set_figheight(8)
ax.set_xlabel('Date',fontsize=20)
plt.xticks(rotation=50)
ax.set_ylabel('Total_Cases')
ax.plot(datafr['Date'],datafr['Total_Cases'])
plt.title('Covid-19 Date wise cases',fontsize=25)
plt.ylabel('Number of cases',fontsize=20)
plt.show()

# %%
fig, ax = plt.subplots()
fig.set_figwidth(20)
fig.set_figheight(8)
Date = datafr['Date']
Cases = datafr['Total_Cases']
sns.barplot(x=Date,y=Cases,palette='tab10')
plt.xticks(rotation=50)
plt.title('Covid-19 Date wise cases',fontsize=25)
plt.ylabel('Number of cases',fontsize=20)
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(18,12))
ax = fig.add_axes([0,0,1,1])
ax.bar(datafr['Date'],datafr['Total_Cases'])
plt.show()
